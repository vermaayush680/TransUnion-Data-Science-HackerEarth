# %% [markdown]
# <a href="https://colab.research.google.com/github/vermaayush680/TransUnion-Data-Science-HackerEarth/blob/main/TransUnion_EDA_and_Modelling_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# The Missing Data has been filled and in this notebook, Data PreProcessing has been done before
# In this notebook,Exploratory Data Analysis and Modelling has been done!!

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score,roc_auc_score,roc_curve

# %% [markdown]
# # Loading Dataset

# %%
df = pd.read_csv('/content/train_final.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1      ID Customer_ID     Month           Name  Age  \
# 0           0             0  0x1602   CUS_0xd40   January  Aaron Maashoh   23
# 1           1             1  0x1603   CUS_0xd40  February  Aaron Maashoh   23
# 2           2             2  0x1604   CUS_0xd40     March  Aaron Maashoh   23
# 3           3             3  0x1605   CUS_0xd40     April  Aaron Maashoh   23
# 4           4             4  0x1606   CUS_0xd40       May  Aaron Maashoh   23
#
#            SSN Occupation  Annual_Income  ...  Credit_Mix  Outstanding_Debt  \
# 0  821-00-0265  Scientist       19114.12  ...           _            809.98
# 1  821-00-0265  Scientist       19114.12  ...        Good            809.98
# 2  821-00-0265  Scientist       19114.12  ...        Good            809.98
# 3  821-00-0265  Scientist       19114.12  ...        Good            809.98
# 4  821-00-0265  Scientist       19114.12  ...        Good            809.98
#
#    Credit_Utilization_Ratio     Credit_History_Age  Payment_of_Min_Amount  \
# 0                 26.822620  22 Years and 1 Months                     No
# 1                 31.944960  22 Years and 3 Months                     No
# 2                 28.609352  22 Years and 3 Months                     No
# 3                 31.377862  22 Years and 4 Months                     No
# 4                 24.797347  22 Years and 5 Months                     No
#
#   Total_EMI_per_month  Amount_invested_monthly  \
# 0           49.574949                80.415295
# 1           49.574949               118.280222
# 2           49.574949                81.699521
# 3           49.574949               199.458074
# 4           49.574949                41.420153
#
#                   Payment_Behaviour  Monthly_Balance  Credit_Score
# 0   High_spent_Small_value_payments       312.494089          Good
# 1    Low_spent_Large_value_payments       284.629162          Good
# 2   Low_spent_Medium_value_payments       331.209863          Good
# 3    Low_spent_Small_value_payments       223.451310          Good
# 4  High_spent_Medium_value_payments       341.489231          Good
#
# [5 rows x 30 columns]

# %%
df.shape
# Out:
# (100000, 30)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'ID', 'Customer_ID', 'Month', 'Name',
#        'Age', 'SSN', 'Occupation', 'Annual_Income', 'Monthly_Inhand_Salary',
#        'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan',
#        'Type_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment',
#        'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Credit_Mix',
#        'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Unnamed: 0                100000 non-null  int64
#  1   Unnamed: 0.1              100000 non-null  int64
#  2   ID                        100000 non-null  object
#  3   Customer_ID               100000 non-null  object
#  4   Month                     100000 non-null  object
#  5   Name                      100000 non-null  object
#  6   Age                       100000 non-null  int64
#  7   SSN                       100000 non-null  object
#  8   Occupation                100000 non-null  object
#  9   Annual_Income             100000 non-null  float64
#  10  Monthly_Inhand_Salary     100000 non-null  float64
#  11  Num_Bank_Accounts         100000 non-null  int64
#  12  Num_Credit_Card           100000 non-null  int64
#  13  Interest_Rate             100000 non-null  int64
#  14  Num_of_Loan               100000 non-null  int64
#  15  Type_of_Loan              100000 non-null  object
#  16  Delay_from_due_date       100000 non-null  int64
#  17  Num_of_Delayed_Payment    100000 non-null  int64
#  18  Changed_Credit_Limit      100000 non-null  float64
#  19  Num_Credit_Inquiries      100000 non-null  float64
#  20  Credit_Mix                100000 non-null  object
#  21  Outstanding_Debt          100000 non-null  float64
#  22  Credit_Utilization_Ratio  100000 non-null  float64
#  23  Credit_History_Age        100000 non-null  object
#  24  Payment_of_Min_Amount     100000 non-null  object
#  25  Total_EMI_per_month       100000 non-null  float64
#  26  Amount_invested_monthly   100000 non-null  float64
#  27  Payment_Behaviour         100000 non-null  object
#  28  Monthly_Balance           100000 non-null  float64
#  29  Credit_Score              100000 non-null  object
# dtypes: float64(9), int64(9), object(12)
# memory usage: 22.9+ MB

# %% [markdown]
# # Data Cleaning and One Hot Encoding

# %%
split1 = lambda a: int(a.split()[0])
split2 = lambda a: int(a.split()[3])/12

# %%
df['Credit_History_Age'] = df['Credit_History_Age'].apply(split1) + df['Credit_History_Age'].apply(split2)

# %%
def fillvalues(data=None,col=None):
  data[col] = data[col].fillna('NAN')
  for i in range(data.shape[0]):
    if data.loc[i,col] == 'NAN':
      j=i+1
      if data.loc[i,'Customer_ID'] == data.loc[j,'Customer_ID']:
        while(data.loc[j,col] == 'NAN'):
          j+=1
        data.loc[i,col]=data.loc[j,col]

  for i in range(data.shape[0]):
    if data.loc[i,col] == 'NAN':
      j=i-1
      if data.loc[i,'Customer_ID'] == data.loc[j,'Customer_ID']:
        data.loc[i,col]=data.loc[j,col]
  return data

# %%
df['Credit_Mix'] = df['Credit_Mix'].replace({'_':np.nan})

# %%
df['Credit_Mix'].isnull().sum()
# Out:
# 20195

# %%
df = fillvalues(data=df,col='Credit_Mix')

# %%
df['Credit_Mix'].isnull().sum()
# Out:
# 0

# %%
df['Payment_of_Min_Amount'].unique()
# Out:
# array(['No', 'NM', 'Yes'], dtype=object)

# %%
df['Payment_of_Min_Amount'] = df['Payment_of_Min_Amount'].replace({'NM':np.nan})

# %%
df['Payment_of_Min_Amount'].isnull().sum()
# Out:
# 12007

# %%
df = fillvalues(data=df,col='Payment_of_Min_Amount')

# %%
df['Payment_of_Min_Amount'].isnull().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'ID', 'Customer_ID', 'Month', 'Name',
#        'Age', 'SSN', 'Occupation', 'Annual_Income', 'Monthly_Inhand_Salary',
#        'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan',
#        'Type_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment',
#        'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Credit_Mix',
#        'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
dummies = pd.get_dummies(df['Payment_of_Min_Amount'])

# %%
df['No'] = dummies['No']
df['Yes'] = dummies['Yes']

# %%
dummies = pd.get_dummies(df['Credit_Mix'])

# %%
dummies.columns
# Out:
# Index(['Bad', 'Good', 'Standard'], dtype='object')

# %%
df['Bad'] = dummies['Bad']
df['Good'] = dummies['Good']
df['Standard'] = dummies['Standard']

# %%
df_new = df.drop(['Unnamed: 0', 'Unnamed: 0.1', 'ID', 'Customer_ID', 'Month', 'Name','SSN', 
         'Occupation', 'Type_of_Loan','Credit_Mix','Credit_History_Age','Payment_of_Min_Amount','Payment_Behaviour'],axis=1)

# %%
df_new['Credit_Score'] = df_new['Credit_Score'].replace({'Good':1,'Standard':0,'Poor':-1})

# %% [markdown]
# Using Integer Coding to Map Credit Score

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Correlation Heatmap

# %%
df_new.corr()
# Out:
#                                Age  Annual_Income  Monthly_Inhand_Salary  \
# Age                       1.000000       0.006412               0.089836
# Annual_Income             0.006412       1.000000               0.030079
# Monthly_Inhand_Salary     0.089836       0.030079               1.000000
# Num_Bank_Accounts        -0.189223      -0.009146              -0.281820
# Num_Credit_Card          -0.148214      -0.001948              -0.216093
# Interest_Rate            -0.216945      -0.006698              -0.299524
# Num_of_Loan              -0.212859      -0.005259              -0.252929
# Delay_from_due_date      -0.173679      -0.010631              -0.248947
# Num_of_Delayed_Payment    0.001424       0.001257               0.000594
# Changed_Credit_Limit     -0.155479       0.000749              -0.172901
# Num_Credit_Inquiries     -0.249840      -0.009850              -0.277235
# Outstanding_Debt         -0.202030      -0.003706              -0.266939
# Credit_Utilization_Ratio  0.025247       0.010316               0.174559
# Total_EMI_per_month       0.001414      -0.000248               0.007517
# Amount_invested_monthly   0.058084       0.020058               0.631594
# Monthly_Balance           0.116603       0.020028               0.700632
# Credit_Score              0.160488       0.008015               0.207504
# No                        0.267665       0.007532               0.305158
# Yes                      -0.267665      -0.007532              -0.305158
# Bad                      -0.183072      -0.000063              -0.251126
# Good                      0.212062       0.010536               0.303377
# Standard                 -0.039166      -0.009669              -0.065246
#
#                           Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  \
# Age                               -0.189223        -0.148214      -0.216945
# Annual_Income                     -0.009146        -0.001948      -0.006698
# Monthly_Inhand_Salary             -0.281820        -0.216093      -0.299524
# Num_Bank_Accounts                  1.000000         0.442559       0.584053
# Num_Credit_Card                    0.442559         1.000000       0.497696
# Interest_Rate                      0.584053         0.497696       1.000000
# Num_of_Loan                        0.471236         0.416956       0.558100
# Delay_from_due_date                0.560350         0.479367       0.589051
# Num_of_Delayed_Payment             0.010455         0.010193       0.012094
# Changed_Credit_Limit               0.330093         0.252346       0.365721
# Num_Credit_Inquiries               0.517480         0.458817       0.631282
# Outstanding_Debt                   0.506858         0.490328       0.629394
# Credit_Utilization_Ratio          -0.071535        -0.055282      -0.075705
# Total_EMI_per_month               -0.006397        -0.006742      -0.005084
# Amount_invested_monthly           -0.184164        -0.144429      -0.197122
# Monthly_Balance                   -0.300374        -0.238873      -0.329262
# Credit_Score                      -0.388353        -0.404291      -0.485399
# No                                -0.582486        -0.414132      -0.631971
# Yes                                0.582486         0.414132       0.631971
# Bad                                0.552669         0.516572       0.627403
# Good                              -0.627507        -0.380080      -0.607084
# Standard                           0.106538        -0.090920       0.023798
#
#                           Num_of_Loan  Delay_from_due_date  \
# Age                         -0.212859            -0.173679
# Annual_Income               -0.005259            -0.010631
# Monthly_Inhand_Salary       -0.252929            -0.248947
# Num_Bank_Accounts            0.471236             0.560350
# Num_Credit_Card              0.416956             0.479367
# Interest_Rate                0.558100             0.589051
# Num_of_Loan                  1.000000             0.500096
# Delay_from_due_date          0.500096             1.000000
# Num_of_Delayed_Payment       0.009629             0.011980
# Changed_Credit_Limit         0.368029             0.292725
# Num_Credit_Inquiries         0.563031             0.539002
# Outstanding_Debt             0.637127             0.571713
# Credit_Utilization_Ratio    -0.100650            -0.063796
# Total_EMI_per_month         -0.001206            -0.003889
# Amount_invested_monthly     -0.166218            -0.164307
# Monthly_Balance             -0.434226            -0.282181
# Credit_Score                -0.357860            -0.431591
# No                          -0.515511            -0.507846
# Yes                          0.515511             0.507846
# Bad                          0.637104             0.647638
# Good                        -0.413111            -0.486997
# Standard                    -0.163490            -0.104315
#
#                           Num_of_Delayed_Payment  Changed_Credit_Limit  ...  \
# Age                                     0.001424             -0.155479  ...
# Annual_Income                           0.001257              0.000749  ...
# Monthly_Inhand_Salary                   0.000594             -0.172901  ...
# Num_Bank_Accounts                       0.010455              0.330093  ...
# Num_Credit_Card                         0.010193              0.252346  ...
# Interest_Rate                           0.012094              0.365721  ...
# Num_of_Loan                             0.009629              0.368029  ...
# Delay_from_due_date                     0.011980              0.292725  ...
# Num_of_Delayed_Payment                  1.000000              0.007315  ...
# Changed_Credit_Limit                    0.007315              1.000000  ...
# Num_Credit_Inquiries                    0.004645              0.377596  ...
# Outstanding_Debt                        0.009329              0.457291  ...
# Credit_Utilization_Ratio                0.001643             -0.047962  ...
# Total_EMI_per_month                     0.000510             -0.002150  ...
# Amount_invested_monthly                -0.000192             -0.115973  ...
# Monthly_Balance                        -0.002634             -0.204759  ...
# Credit_Score                           -0.007953             -0.168862  ...
# No                                     -0.011649             -0.504321  ...
# Yes                                     0.011649              0.504321  ...
# Bad                                     0.008273              0.289707  ...
# Good                                   -0.015558             -0.404072  ...
# Standard                                0.007283              0.125180  ...
#
#                           Credit_Utilization_Ratio  Total_EMI_per_month  \
# Age                                       0.025247             0.001414
# Annual_Income                             0.010316            -0.000248
# Monthly_Inhand_Salary                     0.174559             0.007517
# Num_Bank_Accounts                        -0.071535            -0.006397
# Num_Credit_Card                          -0.055282            -0.006742
# Interest_Rate                            -0.075705            -0.005084
# Num_of_Loan                              -0.100650            -0.001206
# Delay_from_due_date                      -0.063796            -0.003889
# Num_of_Delayed_Payment                    0.001643             0.000510
# Changed_Credit_Limit                     -0.047962            -0.002150
# Num_Credit_Inquiries                     -0.076639            -0.004766
# Outstanding_Debt                         -0.071165            -0.004856
# Credit_Utilization_Ratio                  1.000000             0.001389
# Total_EMI_per_month                       0.001389             1.000000
# Amount_invested_monthly                  -0.003837             0.005985
# Monthly_Balance                           0.246448             0.002451
# Credit_Score                              0.045793             0.004382
# No                                        0.083445             0.002312
# Yes                                      -0.083445            -0.002312
# Bad                                      -0.067153            -0.003945
# Good                                      0.079444             0.005224
# Standard                                 -0.015896            -0.001448
#
#                           Amount_invested_monthly  Monthly_Balance  \
# Age                                      0.058084         0.116603
# Annual_Income                            0.020058         0.020028
# Monthly_Inhand_Salary                    0.631594         0.700632
# Num_Bank_Accounts                       -0.184164        -0.300374
# Num_Credit_Card                         -0.144429        -0.238873
# Interest_Rate                           -0.197122        -0.329262
# Num_of_Loan                             -0.166218        -0.434226
# Delay_from_due_date                     -0.164307        -0.282181
# Num_of_Delayed_Payment                  -0.000192        -0.002634
# Changed_Credit_Limit                    -0.115973        -0.204759
# Num_Credit_Inquiries                    -0.177887        -0.321766
# Outstanding_Debt                        -0.175870        -0.317651
# Credit_Utilization_Ratio                -0.003837         0.246448
# Total_EMI_per_month                      0.005985         0.002451
# Amount_invested_monthly                  1.000000         0.046882
# Monthly_Balance                          0.046882         1.000000
# Credit_Score                             0.155921         0.208355
# No                                       0.199025         0.336135
# Yes                                     -0.199025        -0.336135
# Bad                                     -0.165493        -0.307462
# Good                                     0.197790         0.311314
# Standard                                -0.041026        -0.024405
#
#                           Credit_Score        No       Yes       Bad  \
# Age                           0.160488  0.267665 -0.267665 -0.183072
# Annual_Income                 0.008015  0.007532 -0.007532 -0.000063
# Monthly_Inhand_Salary         0.207504  0.305158 -0.305158 -0.251126
# Num_Bank_Accounts            -0.388353 -0.582486  0.582486  0.552669
# Num_Credit_Card              -0.404291 -0.414132  0.414132  0.516572
# Interest_Rate                -0.485399 -0.631971  0.631971  0.627403
# Num_of_Loan                  -0.357860 -0.515511  0.515511  0.637104
# Delay_from_due_date          -0.431591 -0.507846  0.507846  0.647638
# Num_of_Delayed_Payment       -0.007953 -0.011649  0.011649  0.008273
# Changed_Credit_Limit         -0.168862 -0.504321  0.504321  0.289707
# Num_Credit_Inquiries         -0.434513 -0.629198  0.629198  0.584819
# Outstanding_Debt             -0.386525 -0.491291  0.491291  0.752580
# Credit_Utilization_Ratio      0.045793  0.083445 -0.083445 -0.067153
# Total_EMI_per_month           0.004382  0.002312 -0.002312 -0.003945
# Amount_invested_monthly       0.155921  0.199025 -0.199025 -0.165493
# Monthly_Balance               0.208355  0.336135 -0.336135 -0.307462
# Credit_Score                  1.000000  0.442516 -0.442516 -0.387292
# No                            0.442516  1.000000 -1.000000 -0.454142
# Yes                          -0.442516 -1.000000  1.000000  0.454142
# Bad                          -0.387292 -0.454142  0.454142  1.000000
# Good                          0.427260  0.787714 -0.787714 -0.369149
# Standard                     -0.063146 -0.338609  0.338609 -0.514318
#
#                               Good  Standard
# Age                       0.212062 -0.039166
# Annual_Income             0.010536 -0.009669
# Monthly_Inhand_Salary     0.303377 -0.065246
# Num_Bank_Accounts        -0.627507  0.106538
# Num_Credit_Card          -0.380080 -0.090920
# Interest_Rate            -0.607084  0.023798
# Num_of_Loan              -0.413111 -0.163490
# Delay_from_due_date      -0.486997 -0.104315
# Num_of_Delayed_Payment   -0.015558  0.007283
# Changed_Credit_Limit     -0.404072  0.125180
# Num_Credit_Inquiries     -0.500728 -0.037938
# Outstanding_Debt         -0.388031 -0.285360
# Credit_Utilization_Ratio  0.079444 -0.015896
# Total_EMI_per_month       0.005224 -0.001448
# Amount_invested_monthly   0.197790 -0.041026
# Monthly_Balance           0.311314 -0.024405
# Credit_Score              0.427260 -0.063146
# No                        0.787714 -0.338609
# Yes                      -0.787714  0.338609
# Bad                      -0.369149 -0.514318
# Good                      1.000000 -0.607168
# Standard                 -0.607168  1.000000
#
# [22 rows x 22 columns]

# %%
plt.figure(figsize=(20,15));
sns.heatmap(df_new.corr(),cmap='Blues',annot=True);

# %% [markdown]
# ### Plotting some strong relations from the Correlation Matrix

# %%
plt.figure(figsize=(20,15));
sns.scatterplot(x='Amount_invested_monthly',y='Monthly_Balance',data=df,palette='cool',hue='Credit_Score');
plt.xlabel("Amount Invested")
plt.ylabel("Monthly Balance")
plt.title("Relation Between Balance and Invested Amount")
plt.show()

# %%
plt.figure(figsize=(20,15));
sns.scatterplot(x='Monthly_Inhand_Salary',y='Monthly_Balance',data=df,palette='cool',hue='Credit_Score');
plt.xlabel("Monthly Inhand Salary")
plt.ylabel("Monthly Balance")
plt.title("Relation Between Salary and Invested Amount")
plt.show()

# %% [markdown]
# ### Histogram Plot to see distributions

# %%
for col in df_new.columns:
  plt.figure(figsize=(10,6));
  sns.histplot(data=df_new[col]);
  plt.show();

# %% [markdown]
# Amount_Invested_Monthly and Monthly Balance are highly left skewed.
#
# Also cound of Standard Credit Score is way more than Good and Poor. So we will be using ROC Metric for evaluation of our model which is also in line with the evaluation metric used for evaluation of test data as given in the competition description.

# %% [markdown]
# ### BoxPlot to find Outliers

# %%
for col in df_new.columns:
  plt.figure(figsize=(10,6));
  sns.boxplot(x = df_new[col]);
  plt.show();
  print("\n\n\n")

# %% [markdown]
# # Modelling

# %% [markdown]
# Adding a random feature for feature selection

# %%
df_new.head()
# Out:
#    Age  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0   23       19114.12            1824.843333                  3
# 1   23       19114.12            1824.843333                  3
# 2   23       19114.12            1824.843333                  3
# 3   23       19114.12            1824.843333                  3
# 4   23       19114.12            1824.843333                  3
#
#    Num_Credit_Card  Interest_Rate  Num_of_Loan  Delay_from_due_date  \
# 0                4              3            4                    3
# 1                4              3            4                   -1
# 2                4              3            4                    3
# 3                4              3            4                    5
# 4                4              3            4                    6
#
#    Num_of_Delayed_Payment  Changed_Credit_Limit  ...  \
# 0                       7                 11.27  ...
# 1                       7                 11.27  ...
# 2                       7                 11.27  ...
# 3                       4                  6.27  ...
# 4                       4                 11.27  ...
#
#    Credit_Utilization_Ratio  Total_EMI_per_month  Amount_invested_monthly  \
# 0                 26.822620            49.574949                80.415295
# 1                 31.944960            49.574949               118.280222
# 2                 28.609352            49.574949                81.699521
# 3                 31.377862            49.574949               199.458074
# 4                 24.797347            49.574949                41.420153
#
#    Monthly_Balance  Credit_Score  No  Yes  Bad  Good  Standard
# 0       312.494089             1   1    0    0     1         0
# 1       284.629162             1   1    0    0     1         0
# 2       331.209863             1   1    0    0     1         0
# 3       223.451310             1   1    0    0     1         0
# 4       341.489231             1   1    0    0     1         0
#
# [5 rows x 22 columns]

# %%
X = df_new.drop(['Credit_Score'],axis=1)
y=df_new['Credit_Score']

# %% [markdown]
# ## Test Train Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20,random_state=42)

# %% [markdown]
# ## Normalization and Scaling

# %%
scaler = preprocessing.StandardScaler()

# %%
normalized_x_train = pd.DataFrame(scaler.fit_transform(X_train),columns = X_train.columns)

# %% [markdown]
# ## Modelling

# %%
DR = DecisionTreeClassifier(random_state=42)

# %%
DR.fit(normalized_x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
normalized_x_test = pd.DataFrame(scaler.transform(X_test),columns = X_test.columns)

# %% [markdown]
# ## Prediction

# %%
predicted = DR.predict(normalized_x_test)

# %%
predicted_proba = DR.predict_proba(normalized_x_test)

# %%
actual = y_test

# %%
f1_score(actual,predicted,average='macro')
# Out:
# 0.7150278004606383

# %%
roc_auc_score(actual, predicted_proba, average='weighted',multi_class='ovr')
# Out:
# 0.769032562819573

# %% [markdown]
# # Test Data Prediction

# %%
test_df = pd.read_csv('/content/test.csv')

# %%
test_df.head()
# Out:
#        ID Customer_ID      Month             Name  Age          SSN  \
# 0  0x160a   CUS_0xd40  September    Aaron Maashoh   23  821-00-0265
# 1  0x160b   CUS_0xd40    October    Aaron Maashoh   24  821-00-0265
# 2  0x160c   CUS_0xd40   November    Aaron Maashoh   24  821-00-0265
# 3  0x160d   CUS_0xd40   December    Aaron Maashoh  24_  821-00-0265
# 4  0x1616  CUS_0x21b1  September  Rick Rothackerj   28  004-07-5839
#
#   Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0  Scientist      19114.12            1824.843333                  3  ...
# 1  Scientist      19114.12            1824.843333                  3  ...
# 2  Scientist      19114.12            1824.843333                  3  ...
# 3  Scientist      19114.12                    NaN                  3  ...
# 4    _______      34847.84            3037.986667                  2  ...
#
#    Num_Credit_Inquiries  Credit_Mix Outstanding_Debt Credit_Utilization_Ratio  \
# 0                2022.0        Good           809.98                35.030402
# 1                   4.0        Good           809.98                33.053114
# 2                   4.0        Good           809.98                33.811894
# 3                   4.0        Good           809.98                32.430559
# 4                   5.0        Good           605.03                25.926822
#
#        Credit_History_Age Payment_of_Min_Amount Total_EMI_per_month  \
# 0   22 Years and 9 Months                    No           49.574949
# 1  22 Years and 10 Months                    No           49.574949
# 2                     NaN                    No           49.574949
# 3   23 Years and 0 Months                    No           49.574949
# 4   27 Years and 3 Months                    No           18.816215
#
#    Amount_invested_monthly                 Payment_Behaviour  \
# 0       236.64268203272135    Low_spent_Small_value_payments
# 1       21.465380264657146  High_spent_Medium_value_payments
# 2       148.23393788500925   Low_spent_Medium_value_payments
# 3        39.08251089460281  High_spent_Medium_value_payments
# 4       39.684018417945296   High_spent_Large_value_payments
#
#       Monthly_Balance
# 0  186.26670208571772
# 1  361.44400385378196
# 2  264.67544623342997
# 3  343.82687322383634
# 4   485.2984336755923
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Cleaning and PreProcessing Test Data

# %%
test_df.isnull().sum()
# Out:
# ID                             0
# Customer_ID                    0
# Month                          0
# Name                        5015
# Age                            0
# SSN                            0
# Occupation                     0
# Annual_Income                  0
# Monthly_Inhand_Salary       7498
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                    0
# Type_of_Loan                5704
# Delay_from_due_date            0
# Num_of_Delayed_Payment      3498
# Changed_Credit_Limit           0
# Num_Credit_Inquiries        1035
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          4470
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Amount_invested_monthly     2271
# Payment_Behaviour              0
# Monthly_Balance              562
# dtype: int64

# %% [markdown]
# Filtering only the columns used for training the model

# %%
test_df.isnull().sum()
# Out:
# ID                             0
# Customer_ID                    0
# Month                          0
# Name                        5015
# Age                            0
# SSN                            0
# Occupation                     0
# Annual_Income                  0
# Monthly_Inhand_Salary       7498
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                    0
# Type_of_Loan                5704
# Delay_from_due_date            0
# Num_of_Delayed_Payment      3498
# Changed_Credit_Limit           0
# Num_Credit_Inquiries        1035
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          4470
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Amount_invested_monthly     2271
# Payment_Behaviour              0
# Monthly_Balance              562
# dtype: int64

# %%
test_df = test_df.ffill()

# %%
cleanfunc = lambda a: str(a)[:-1] if str(a)[-1] == '_' else a

# %%
cleanfunc("24_")
# Out:
# '24'

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        50000 non-null  object
#  1   Customer_ID               50000 non-null  object
#  2   Month                     50000 non-null  object
#  3   Name                      50000 non-null  object
#  4   Age                       50000 non-null  object
#  5   SSN                       50000 non-null  object
#  6   Occupation                50000 non-null  object
#  7   Annual_Income             50000 non-null  object
#  8   Monthly_Inhand_Salary     50000 non-null  float64
#  9   Num_Bank_Accounts         50000 non-null  int64
#  10  Num_Credit_Card           50000 non-null  int64
#  11  Interest_Rate             50000 non-null  int64
#  12  Num_of_Loan               50000 non-null  object
#  13  Type_of_Loan              50000 non-null  object
#  14  Delay_from_due_date       50000 non-null  int64
#  15  Num_of_Delayed_Payment    50000 non-null  object
#  16  Changed_Credit_Limit      50000 non-null  object
#  17  Num_Credit_Inquiries      50000 non-null  float64
#  18  Credit_Mix                50000 non-null  object
#  19  Outstanding_Debt          50000 non-null  object
#  20  Credit_Utilization_Ratio  50000 non-null  float64
#  21  Credit_History_Age        50000 non-null  object
#  22  Payment_of_Min_Amount     50000 non-null  object
#  23  Total_EMI_per_month       50000 non-null  float64
#  24  Amount_invested_monthly   50000 non-null  object
#  25  Payment_Behaviour         50000 non-null  object
#  26  Monthly_Balance           50000 non-null  object
# dtypes: float64(4), int64(4), object(19)
# memory usage: 10.3+ MB

# %% [markdown]
# ## Converting type to integer

# %%
def applyfunc(col=None):
  test_df[col] = test_df[col].apply(cleanfunc)
  test_df[col] = test_df[col].apply(pd.to_numeric)

# %%
applyfunc('Age')

# %%
applyfunc('Annual_Income')

# %%
applyfunc('Num_of_Loan')

# %%
applyfunc('Num_of_Delayed_Payment')

# %%
applyfunc('Changed_Credit_Limit')

# %%
test_df['Changed_Credit_Limit'] = test_df['Changed_Credit_Limit'].ffill()

# %%
applyfunc('Outstanding_Debt')

# %%
test_df['Amount_invested_monthly'] = test_df['Amount_invested_monthly'].replace({'__10000__':np.nan})

# %%
test_df['Amount_invested_monthly'] = test_df['Amount_invested_monthly'].ffill()

# %%
applyfunc('Amount_invested_monthly')

# %%
test_df['Monthly_Balance'] = test_df['Monthly_Balance'].replace({'__-333333333333333333333333333__':np.nan})

# %%
test_df['Monthly_Balance'] = test_df['Monthly_Balance'].ffill()

# %%
applyfunc('Monthly_Balance')

# %%
test_df['Random_Col'] = np.random.random(test_df.shape[0])

# %%
def fillvalues1(data=None,col=None):
  data[col] = data[col].fillna('NAN')
  for i in range(data.shape[0]):
    if data.loc[i,col] == 'NAN':
      j=i
      if data.loc[i,'Customer_ID'] == data.loc[j,'Customer_ID']:
        j=i-1
      else:
        j=i+1
      data.loc[i,col]=data.loc[j,col]
  return data

# %%
test_df['Credit_Mix'] = test_df['Credit_Mix'].replace({'_':np.nan})

# %%
test_df['Credit_Mix'].isnull().sum()
# Out:
# 9805

# %%
test_df = fillvalues1(data=test_df,col='Credit_Mix')

# %%
test_df['Credit_Mix'].isnull().sum()
# Out:
# 0

# %%
test_df[test_df['Credit_Mix']=='NAN']
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Random_Col]
# Index: []
#
# [0 rows x 28 columns]

# %%
test_df['Payment_of_Min_Amount'].unique()
# Out:
# array(['No', 'Yes', 'NM'], dtype=object)

# %%
test_df['Payment_of_Min_Amount'] = test_df['Payment_of_Min_Amount'].replace({'NM':np.nan})

# %%
test_df['Payment_of_Min_Amount'].isnull().sum()
# Out:
# 5993

# %%
test_df = fillvalues(data=test_df,col='Payment_of_Min_Amount')

# %%
test_df['Payment_of_Min_Amount'].isnull().sum()
# Out:
# 0

# %%
dummies = pd.get_dummies(test_df['Payment_of_Min_Amount'])

# %%
test_df['No'] = dummies['No']
test_df['Yes'] = dummies['Yes']

# %%
dummies = pd.get_dummies(test_df['Credit_Mix'])

# %%
dummies.columns
# Out:
# Index(['Bad', 'Good', 'Standard'], dtype='object')

# %%
test_df['Bad'] = dummies['Bad']
test_df['Good'] = dummies['Good']
test_df['Standard'] = dummies['Standard']

# %%
test_df = test_df[X_train.columns]

# %%
normalized_x_test = pd.DataFrame(scaler.transform(test_df),columns = test_df.columns)

# %%
predicted = DR.predict(normalized_x_test)

# %%
predicted
# Out:
# array([ 0, -1,  1, ..., -1, -1, -1])

# %% [markdown]
# ### Loading the test data again for getting ID!!

# %%
df_test = pd.read_csv('/content/test.csv')

# %%
df_test.head()
# Out:
#        ID Customer_ID      Month             Name  Age          SSN  \
# 0  0x160a   CUS_0xd40  September    Aaron Maashoh   23  821-00-0265
# 1  0x160b   CUS_0xd40    October    Aaron Maashoh   24  821-00-0265
# 2  0x160c   CUS_0xd40   November    Aaron Maashoh   24  821-00-0265
# 3  0x160d   CUS_0xd40   December    Aaron Maashoh  24_  821-00-0265
# 4  0x1616  CUS_0x21b1  September  Rick Rothackerj   28  004-07-5839
#
#   Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0  Scientist      19114.12            1824.843333                  3  ...
# 1  Scientist      19114.12            1824.843333                  3  ...
# 2  Scientist      19114.12            1824.843333                  3  ...
# 3  Scientist      19114.12                    NaN                  3  ...
# 4    _______      34847.84            3037.986667                  2  ...
#
#    Num_Credit_Inquiries  Credit_Mix Outstanding_Debt Credit_Utilization_Ratio  \
# 0                2022.0        Good           809.98                35.030402
# 1                   4.0        Good           809.98                33.053114
# 2                   4.0        Good           809.98                33.811894
# 3                   4.0        Good           809.98                32.430559
# 4                   5.0        Good           605.03                25.926822
#
#        Credit_History_Age Payment_of_Min_Amount Total_EMI_per_month  \
# 0   22 Years and 9 Months                    No           49.574949
# 1  22 Years and 10 Months                    No           49.574949
# 2                     NaN                    No           49.574949
# 3   23 Years and 0 Months                    No           49.574949
# 4   27 Years and 3 Months                    No           18.816215
#
#    Amount_invested_monthly                 Payment_Behaviour  \
# 0       236.64268203272135    Low_spent_Small_value_payments
# 1       21.465380264657146  High_spent_Medium_value_payments
# 2       148.23393788500925   Low_spent_Medium_value_payments
# 3        39.08251089460281  High_spent_Medium_value_payments
# 4       39.684018417945296   High_spent_Large_value_payments
#
#       Monthly_Balance
# 0  186.26670208571772
# 1  361.44400385378196
# 2  264.67544623342997
# 3  343.82687322383634
# 4   485.2984336755923
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Getting the Predictions as the Sample Submission Format

# %%
output = pd.DataFrame({
    'ID':df_test['ID'],
    'Credit_Score':predicted
})

# %%
output.head()
# Out:
#        ID  Credit_Score
# 0  0x160a             0
# 1  0x160b            -1
# 2  0x160c             1
# 3  0x160d             1
# 4  0x1616             1

# %% [markdown]
# ### Decoding the Credit Score

# %%
output['Credit_Score'] = output['Credit_Score'].replace({1:'Good',0:'Standard',-1:'Poor'})

# %%
output.head()
# Out:
#        ID Credit_Score
# 0  0x160a     Standard
# 1  0x160b         Poor
# 2  0x160c         Good
# 3  0x160d         Good
# 4  0x1616         Good

# %% [markdown]
# ## Saving the Output

# %%
output.to_csv('output.csv')
